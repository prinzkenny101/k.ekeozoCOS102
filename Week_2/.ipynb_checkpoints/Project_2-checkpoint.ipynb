# %% [markdown]
# START
#
# PRINT "Choose equation to solve"
# PRINT "1 – Cubic Equation"
# PRINT "2 – Quartic Equation"
# PRINT "3 – Quadratic Equation"
#
# INPUT Choice
#
# IF Choice = 1 THEN
#     PRINT "Enter coefficients A, B, C, D"
#     INPUT A, B, C, D
#     Calculate cubic roots
#     PRINT roots
#
# ELSE IF Choice = 2 THEN
#     PRINT "Enter coefficients A, B, C, D, E"
#     INPUT A, B, C, D, E
#     Calculate quartic roots
#     PRINT roots
#
# ELSE IF Choice = 3 THEN
#     PRINT "Enter coefficients A, B, C"
#     INPUT A, B, C
#     Compute discriminant
#     Calculate quadratic roots
#     PRINT roots
#
# ELSE
#     PRINT "Invalid choice"
#
# STOP

# %%
import math as mt

# %%
print("Choose equation to solve")
print("1 - Cubic equation")
print("2 - Quartic equation")
print("3 - Quadratic equation")

choice = int(input("Enter choice: "))

if choice == 1:
    print("Enter coefficients A, B, C, D")
    A = float(input("A: "))
    B = float(input("B: "))
    C = float(input("C: "))
    D = float(input("D: "))
    
    print("Cubic equation selected")

elif choice == 2:
    print("Enter coefficients A, B, C, D, E")
    A = float(input("A: "))
    B = float(input("B: "))
    C = float(input("C: "))
    D = float(input("D: "))
    E = float(input("E: "))
    
    print("Quartic equation selected")

elif choice == 3:
    print("Enter coefficients A, B, C")
    A = float(input("A: "))
    B = float(input("B: "))
    C = float(input("C: "))

    discriminant = (B ** 2) - (4 * A * C)

    print("Discriminant =", discriminant)

else:
    print("Invalid choice")
# Out:
# Choose equation to solve
# 1 - Cubic equation
# 2 - Quartic equation
# 3 - Quadratic equation
# Enter choice:  1
# Enter coefficients A, B, C, D
# A:  5
# B:  5
# C:  6
# D:  7
# Cubic equation selected
