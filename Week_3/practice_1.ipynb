# %%
def printme( str ):
    #This is a print fuction
    print (str);
    return;

printme("I'm first call to user defined function!");
printme("Again second call to the same function!");
printme("Let's try a third one");
# Out:
# I'm first call to user defined function!
# Again second call to the same function!
# Let's try a third one

# %%
def changeme( mylist ):
    #This changes a passed list
    mylist.append([1,2,3,4])
    print ("Values inside the function: ", mylist)
    return
mylist = [10,20,30]
changeme( mylist )
print ("Values outside the function: ", mylist)
# Out:
# Values inside the function:  [10, 20, 30, [1, 2, 3, 4]]
# Values outside the function:  [10, 20, 30, [1, 2, 3, 4]]

# %%
def changeme( mylist ):
    #This changes a passed lidt
    mylist = [1,2,3,4];
    print("Values inside the function: ", mylist)
    return
mylist = [10,20,30];
changeme( mylist );
print ("Values outside the dunction: ", mylist)
# Out:
# Values inside the function:  [1, 2, 3, 4]
# Values outside the dunction:  [10, 20, 30]

# %%
def printme( str ):
    #This prints a passed string
    print (str);
    return;
printme("Learning how to use functions with python");
# Out:
# Learning how to use functions with python

# %%
def printme ( str ):
    #This prints a passed string
    print (str);
    return;
printme( str = "My string");
# Out:
# My string

# %%
def printinfo( name, age ):
    #Test function
    print ("Name: ", name);
    print ("Age: ", age);
    return;
printinfo( age=50, name="miki" );
# Out:
# Name:  miki
# Age:  50

# %%
def printinfo( name, age = 35 ):
    #Test function
    print ("Name: ", name);
    print ("Age: ", age);
    return;
printinfo( age=50, name="miki" );
printinfo( name="miki" );
# Out:
# Name:  miki
# Age:  50
# Name:  miki
# Age:  35

# %%
def printinfo( arg1, arg2, *vartuple ):
    #This is test
    print ("Output is: ")
    print (arg1)
    print (arg2)
    for var in vartuple:
        print (var)
        return;
printinfo( 10, 20 );
printinfo( 70, 60, 50 );
# Out:
# Output is:
# 10
# 20
# Output is:
# 70
# 60
# 50

# %%
total = 50; # This is global variable.
def sum( arg1, arg2 ):
    # Add both the parameters
    total = arg1 + arg2;
    print ("Inside the function local total : ", total)
    return total;
# Now you can call sum function
sum ( 10, 20 );
print ("Outside the function global total : ", total)
# Out:
# Inside the function local total :  60
# Outside the function global total :  50

# %%
def swap(x, y):
    global a 
    a = "Lawal"
    x,y = y,x
    b = "Chris"
    b = "Edward"
    c = "Lola"
    print(a,b,x,y)
    a = "Mary"
swap("Tina","Tolu")
print (a)
# Out:
# Lawal Edward Tolu Tina
# Mary
