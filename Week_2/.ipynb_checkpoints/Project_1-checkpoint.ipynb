# %% [markdown]
# #Algorithm to store checkout after purchase
# INPUT "Do you want to checkout now?"
# IF user wants to checkout
# PRINT product
# ELSE return to cart
# INPUT payment method
# IF payment method is valid
# PRINT user's payment method
# ELSE ask for the correct payment method

# %% [markdown]
# ![diagram-export-09-03-2026-12_15_36(1).png](attachment:4652675c-3990-42d9-9eeb-502c214e2b44.png)

# %% [markdown]
# ![project_I_B.png](attachment:ccf56011-71cc-462b-9ba9-05fba39ba5c1.png)

# %% [markdown]
# #Algorithm to swap the ages of two names
# PRINT "Enter name 1"
# INPUT Name_1
#
# PRINT "Enter age of name 1"
# INPUT Age_1
#
# PRINT "Enter name 2"
# INPUT Name_2
#
# PRINT "Enter age of name 2"
# INPUT Age_2
#
# Temp = Age_1
# Age_1 = Age_2
# Age_2 = Temp
#
# PRINT "After swapping:"
# PRINT Name_1, Age_1
# PRINT Name_2, Age_2
