# %% [markdown]
# START
#
# INPUT years of experience
# INPUT age
#
# IF staff has more than 25 years of experience and age is equal to or more than 55
# PRINT Your Annual Tax Revenue(ATR) is N5,600,000
#
# IF staff has more than 20 years of experience and age is equal to more than 45
# PRINT Your ATR is N4,480,000
#
# IF the staff has more than 10 years of experience and age is equal to more than 35
# PRINT Your ATR is N1,500,000
#
# ELSE
# PRINT Your ATR is N550,000
#
# STOP

# %%
print("--- Welcome to Izifin Technology ---")

#Collecting inputs
years_of_experience = int(input("How many years of experience do you have? : "))
age = int(input("How old are you? : "))

#Conditional statements

if years_of_experience > 25 and age >= 55:
    print("Your Annual Tax Revenue is N5,600,000")
elif years_of_experience > 20 and age >= 45:
    print("Your Annual Tax Revenue is N4,480,000")
elif years_of_experience > 10 and age >= 35:
    print("Your Annual Tax Revenue is N1,500,000")
else:
    print("Your Annual Tax Revenue is N550,000")
# Out:
# --- Izifin Technology ---
# How many years of experience do you have? :  27
# How old are you? :  59
# Your Annual Tax Revenue is N5,600,000
